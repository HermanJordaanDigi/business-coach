# %% [markdown]
# # Business Coaching Analytics - Visualization Gallery
#
# This notebook showcases all the visualizations generated for the business coaching analytics project.
#
# ## Overview
#
# This gallery includes:
# 1. Monthly Revenue Trends
# 2. Product Performance Analysis
# 3. Closer Performance Metrics
# 4. Geographic Distribution
# 5. Cash Collection Analysis
# 6. Upsell Conversion Metrics
# 7. Revenue Heatmaps
# 8. Deal Size Distributions
# 9. Revenue vs Cash Collected Analysis
# 10. Interactive Dashboard

# %%
import sys
from pathlib import Path
from IPython.display import Image, HTML, display
import pandas as pd

# Add src to path
sys.path.append(str(Path.cwd().parent / 'src'))

# Import config
from config import VISUALIZATIONS_DIR

# %% [markdown]
# ## 1. Monthly Revenue Trend
#
# This line chart shows the revenue trend over the 11 months of 2025. It helps identify seasonal patterns and growth trajectory.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '01_revenue_trend.png')))

# %% [markdown]
# ## 2. Product Performance Comparison
#
# This chart compares the three products by total revenue and deal volume, helping identify which products are top performers.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '02_product_performance.png')))

# %% [markdown]
# ## 3. Closer Leaderboard
#
# Performance metrics for each sales closer including total revenue, deal count, and average deal size.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '03_closer_leaderboard.png')))

# %% [markdown]
# ## 4. Geographic Distribution
#
# Donut charts showing revenue and deal distribution across US, UK, and EU markets.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '04_geographic_distribution.png')))

# %% [markdown]
# ## 5. Cash Collection Funnel
#
# Analysis of cash collection efficiency, showing the gap between revenue generated and cash actually collected.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '05_cash_collection_funnel.png')))

# %% [markdown]
# ## 6. Upsell Conversion Rates
#
# Upsell success rates broken down by product and by closer, highlighting which products and which closers excel at upselling.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '06_upsell_conversion.png')))

# %% [markdown]
# ## 7. Revenue Heatmap
#
# A heatmap showing revenue patterns by product and month, making it easy to spot seasonal trends and product performance over time.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '07_revenue_heatmap.png')))

# %% [markdown]
# ## 8. Deal Size Distribution
#
# Box plot and violin plot showing the distribution of deal sizes by product, including median, quartiles, and outliers.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '08_deal_size_distribution.png')))

# %% [markdown]
# ## 9. Revenue vs Cash Collected
#
# Scatter plot comparing revenue to cash collected for each deal, colored by product. The red dashed line represents 100% collection rate.

# %%
display(Image(filename=str(VISUALIZATIONS_DIR / '09_revenue_vs_cash.png')))

# %% [markdown]
# ## 10. Interactive Dashboard
#
# An interactive Plotly dashboard combining multiple key metrics in one view. Open the HTML file for full interactivity.
#
# **Note:** Open `outputs/visualizations/10_interactive_dashboard.html` in a browser for the fully interactive version.

# %%
# Display static version
display(Image(filename=str(VISUALIZATIONS_DIR / '10_interactive_dashboard.png')))

# %%
# Display interactive version (if running in Jupyter)
dashboard_path = VISUALIZATIONS_DIR / '10_interactive_dashboard.html'
if dashboard_path.exists():
    display(HTML(f'<iframe src="{dashboard_path}" width="100%" height="1200px"></iframe>'))

# %% [markdown]
# ## Summary
#
# All visualizations have been generated and can be found in the `outputs/visualizations/` directory.
#
# ### Key Insights from Visualizations:
#
# 1. **Revenue Trends**: Clear visibility into monthly revenue patterns and seasonality
# 2. **Product Performance**: Compare which products generate the most revenue and deals
# 3. **Sales Team Performance**: Identify top performers and coaching opportunities
# 4. **Geographic Insights**: Understand market distribution and regional performance
# 5. **Cash Flow**: Monitor collection efficiency and identify potential issues
# 6. **Upsell Success**: Track upsell conversion rates to optimize sales strategy
# 7. **Deal Analysis**: Understand deal size distributions and outliers
#
# ### Next Steps:
#
# - Use these visualizations in business reviews and presentations
# - Incorporate into automated reporting dashboards
# - Share with stakeholders via the API endpoints
# - Continue monitoring trends as new data comes in
